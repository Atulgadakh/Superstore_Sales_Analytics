# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r"C:\Users\hp\Desktop\New folder (3)")

# %%
E_commerece=pd.read_csv("E_comm.csv",encoding='latin1')

# %%
# EDA

# %%
E_commerece.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
E_commerece.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
E_commerece.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
E_commerece.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
E_commerece.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
E_commerece["Order Date"] = pd.to_datetime(E_commerece["Order Date"])

# %%
E_commerece.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
E_commerece["Product Name"].value_counts()[0:10]
# Out:
# Product Name
# Staple envelope                                              48
# Staples                                                      46
# Easy-staple paper                                            46
# Avery Non-Stick Binders                                      20
# Staples in misc. colors                                      19
# Staple remover                                               18
# KI Adjustable-Height Table                                   18
# Storex Dura Pro Binders                                      17
# Staple-based wall hangings                                   16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling    15
# Name: count, dtype: int64

# %%
plt.pie(E_commerece["Product Name"].value_counts().head(10), labels=E_commerece["Product Name"].value_counts().head(10).index, autopct="%0.1f%%")
plt.title("Top 10 Products Distribution")
plt.show()

# %%
E_commerece["Region"].value_counts()[0:10]
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
plt.pie(E_commerece["Region"].value_counts(), labels= E_commerece["Region"].value_counts().keys(),autopct="%0.1f%%")
plt.title("Region Distribution")
plt.show()

# %%
E_commerece["Region"].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
E_commerece["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
plt.bar(E_commerece["Region"].unique(), E_commerece.groupby("Region")["Sales"].sum(),color="orange")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.title("Total Sales in Each Region")
plt.show()

# %%
plt.bar(E_commerece["Region"].unique(), E_commerece.groupby("Region")["Profit"].sum(),color="green")
plt.xlabel("Region")
plt.ylabel("Total Profit")
plt.title("Total Profit in Each Region")
plt.show()

# %%
E_commerece.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
E_commerece["Product Name"][0:5]
# Out:
# 0                    Bush Somerset Collection Bookcase
# 1    Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2    Self-Adhesive Address Labels for Typewriters b...
# 3        Bretford CR4500 Series Slim Rectangular Table
# 4                       Eldon Fold 'N Roll Cart System
# Name: Product Name, dtype: object

# %%
E_commerece["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
top_sales=E_commerece.sort_values(by='Sales', ascending=False)
top_sales
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02   10/9/2016  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23   3/25/2017     First Class
# 2623    2624  CA-2017-127180 2017-10-22  10/24/2017     First Class
# 4190    4191  CA-2017-166709 2017-11-17  11/22/2017  Standard Class
# ...      ...             ...        ...         ...             ...
# 2106    2107  US-2014-152723 2014-09-26   9/26/2014        Same Day
# 4711    4712  CA-2014-112403 2014-03-31   3/31/2014        Same Day
# 8658    8659  CA-2016-168361 2016-06-21   6/25/2016  Standard Class
# 9292    9293  CA-2017-124114 2017-03-02    3/2/2017        Same Day
# 4101    4102  US-2017-102288 2017-06-19   6/23/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
top_sales["Product Name"][0:5]
# Out:
# 2697    Cisco TelePresence System EX90 Videoconferenci...
# 6826                Canon imageCLASS 2200 Advanced Copier
# 8153                Canon imageCLASS 2200 Advanced Copier
# 2623                Canon imageCLASS 2200 Advanced Copier
# 4190                Canon imageCLASS 2200 Advanced Copier
# Name: Product Name, dtype: object

# %%
top_sales["Sales"]
# Out:
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
#           ...
# 2106        0.876
# 4711        0.852
# 8658        0.836
# 9292        0.556
# 4101        0.444
# Name: Sales, Length: 9994, dtype: float64

# %%
plt.figure(figsize=(9, 7))
plt.bar(top_sales["Product Name"][0:5],top_sales["Sales"][0:5])
plt.title("Productwise Sales and Profit  Distribution")
plt.show()

# %%
top_Profit=E_commerece.sort_values(by='Sales', ascending=False)
top_Profit
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02   10/9/2016  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23   3/25/2017     First Class
# 2623    2624  CA-2017-127180 2017-10-22  10/24/2017     First Class
# 4190    4191  CA-2017-166709 2017-11-17  11/22/2017  Standard Class
# ...      ...             ...        ...         ...             ...
# 2106    2107  US-2014-152723 2014-09-26   9/26/2014        Same Day
# 4711    4712  CA-2014-112403 2014-03-31   3/31/2014        Same Day
# 8658    8659  CA-2016-168361 2016-06-21   6/25/2016  Standard Class
# 9292    9293  CA-2017-124114 2017-03-02    3/2/2017        Same Day
# 4101    4102  US-2017-102288 2017-06-19   6/23/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
plt.figure(figsize=(9, 7))
plt.bar(top_Profit["Product Name"][0:5],top_Profit["Sales"][0:5],color="orange")
plt.title("Productwise Profit  Distribution")
plt.show()

# %%
E_commerece["order_month"]=E_commerece["Order Date"].dt.month_name()

# %%
E_commerece["order_year"] = E_commerece["Order Date"].dt.year

# %%
E_commerece
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 1          2  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 2          3  CA-2016-138688 2016-06-12   6/16/2016    Second Class
# 3          4  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 4          5  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2014-110422 2014-01-21   1/23/2014    Second Class
# 9990    9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
E_commerece["order_month"].shape
# Out:
# (9994,)

# %%
plt.plot(E_commerece["order_year"].value_counts().sort_index(), E_commerece.groupby("order_year")["Sales"].sum())
plt.xlabel('Order Year')
plt.ylabel('Total Sales')
plt.title('Total Sales Over the Years')
plt.show()

# %%
plt.plot(E_commerece["order_year"].value_counts().sort_index(), E_commerece.groupby("order_year")["Profit"].sum())
plt.xlabel('Order Year')
plt.ylabel('Total Profit')
plt.title('Total Profit Over the Years')
plt.show()

# %%
E_commerece.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Time Series Analysis

# %%
time_series=pd.DataFrame({'Order Date': E_commerece['Order Date'], 'Sales': E_commerece['Sales']})
time_series
# Out:
#      Order Date     Sales
# 0    2016-11-08  261.9600
# 1    2016-11-08  731.9400
# 2    2016-06-12   14.6200
# 3    2015-10-11  957.5775
# 4    2015-10-11   22.3680
# ...         ...       ...
# 9989 2014-01-21   25.2480
# 9990 2017-02-26   91.9600
# 9991 2017-02-26  258.5760
# 9992 2017-02-26   29.6000
# 9993 2017-05-04  243.1600
#
# [9994 rows x 2 columns]

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  9994 non-null   datetime64[ns]
#  1   Sales       9994 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 156.3 KB

# %%
time_series=time_series.index = time_series['Order Date']

# %%
time_series
# Out:
# Order Date
# 2016-11-08   2016-11-08
# 2016-11-08   2016-11-08
# 2016-06-12   2016-06-12
# 2015-10-11   2015-10-11
# 2015-10-11   2015-10-11
#                 ...
# 2014-01-21   2014-01-21
# 2017-02-26   2017-02-26
# 2017-02-26   2017-02-26
# 2017-02-26   2017-02-26
# 2017-05-04   2017-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
df1=time_series.head(20)

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 13,6
df1.plot()
plt.show()

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 13,6
df1.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(df1, model='additive', period=12)
decompose.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 from statsmodels.tsa.seasonal import seasonal_decompose
# ----> 2 decompose = seasonal_decompose(df1, model='additive', period=12)
#       3 decompose.plot()
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\seasonal.py:171, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     166         raise ValueError(
#     167             "You must specify a period or x must be a pandas object with "
#     168             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     169         )
#     170 if x.shape[0] < 2 * pfreq:
# --> 171     raise ValueError(
#     172         f"x must have 2 complete cycles requires {2 * pfreq} "
#     173         f"observations. x only has {x.shape[0]} observation(s)"
# ...
